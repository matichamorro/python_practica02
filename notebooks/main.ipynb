# %%
import sys
sys.path.append('..src')

# %%
# Ejercicio 10
from ranking import generate_ranking, rounds
generate_ranking(rounds)
# Out:
# Ronda 1 - Entrada:
#     Ganador/a: Camila (26 pts)
#     2. Camila (26 pts)
#     3. Valentina (24 pts)
#     4. Lucía (24 pts)
#     5. Mateo (22 pts)
#     6. Santiago (19 pts)
#
# Ronda 2 - Plato principal:
#     Ganador/a: Valentina (26 pts)
#     2. Valentina (26 pts)
#     3. Santiago (25 pts)
#     4. Mateo (24 pts)
#     5. Lucía (22 pts)
#     6. Camila (20 pts)
#
# Ronda 3 - Postre:
#     Ganador/a: Lucía (27 pts)
#     2. Lucía (27 pts)
#     3. Mateo (26 pts)
#     4. Camila (24 pts)
#     5. Valentina (22 pts)
#     6. Santiago (20 pts)
#
# Ronda 4 - Cocina internacional:
#     Ganador/a: Valentina (26 pts)
#     2. Valentina (26 pts)
#     3. Camila (25 pts)
#     4. Santiago (24 pts)
#     5. Lucía (22 pts)
#     6. Mateo (20 pts)
#
# Ronda 5 - Final libre:
#     Ganador/a: Santiago (27 pts)
#     2. Santiago (27 pts)
#     3. Valentina (26 pts)
#     4. Mateo (25 pts)
#     5. Lucía (23 pts)
#     6. Camila (21 pts)
#
# Tabla de posiciones final:
# Cocinero     Puntaje     Rondas ganadas     Mejor ronda     Promedio
# --------------------------------------------------------------------
# Valentina      124             2               26             24.8
# Mateo          117             0               26             23.4
# Camila         116             1               26             23.2
# Santiago       115             1               27             23.0
# Lucía          118             1               27             23.6
# --------------------------------------------------------------------

# %%
from ejercicio01 import text_stats
from ejercicio01 import text
text_stats(text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from ejercicio01 import text_stats
#       2 from ejercicio01 import text
#       3 text_stats(text)
#
# ImportError: cannot import name 'text_stats' from 'ejercicio01' (c:\Users\Matias Chamorro\Repositorios\python_practica02\notebooks\..\src\ejercicio01.py)
