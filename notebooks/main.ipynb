# %%
import sys
sys.path.append('..\src')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Matias Chamorro\AppData\Local\Temp\ipykernel_12024\596019446.py:2: SyntaxWarning: invalid escape sequence '\s'
#   sys.path.append('..\src')

# %%
# Ejercicio 10
from ranking import generate_ranking, rounds
generate_ranking(rounds)
# Out:
# Ronda 1 - Entrada:
#     Ganador/a: Camila (26 pts)
#     2. Valentina (24 pts)
#     3. Lucía (24 pts)
#     4. Mateo (22 pts)
#     5. Santiago (19 pts)
#
# Ronda 2 - Plato principal:
#     Ganador/a: Valentina (26 pts)
#     2. Santiago (25 pts)
#     3. Mateo (24 pts)
#     4. Lucía (22 pts)
#     5. Camila (20 pts)
#
# Ronda 3 - Postre:
#     Ganador/a: Lucía (27 pts)
#     2. Mateo (26 pts)
#     3. Camila (24 pts)
#     4. Valentina (22 pts)
#     5. Santiago (20 pts)
#
# Ronda 4 - Cocina internacional:
#     Ganador/a: Valentina (26 pts)
#     2. Camila (25 pts)
#     3. Santiago (24 pts)
#     4. Lucía (22 pts)
#     5. Mateo (20 pts)
#
# Ronda 5 - Final libre:
#     Ganador/a: Santiago (27 pts)
#     2. Valentina (26 pts)
#     3. Mateo (25 pts)
#     4. Lucía (23 pts)
#     5. Camila (21 pts)
#
# Tabla de posiciones final:
# Cocinero     Puntaje     Rondas ganadas     Mejor ronda     Promedio
# --------------------------------------------------------------------
# Valentina      72              2                26            14.4
# Mateo          117             0                26            23.4
# Camila         90              1                25            18.0
# Santiago       88              1                25            17.6
# Lucía          91              1                24            18.2
# --------------------------------------------------------------------

# %%
# Ejercicio 1
from text_stats import text_stats, text
text_stats(text)

# %%
# Ejercicio 2
import playlist_duration

# %%
#Ejercicio 3
import spoiler_filter

# %%
# Ejercicio 4
import email_validation
