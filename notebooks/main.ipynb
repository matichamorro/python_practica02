# %%
import sys
sys.path.append('..\src')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Matias Chamorro\AppData\Local\Temp\ipykernel_7408\596019446.py:2: SyntaxWarning: invalid escape sequence '\s'
#   sys.path.append('..\src')

# %%
# Ejercicio 10
from ranking import generate_ranking, rounds
generate_ranking(rounds)

# %%
# Ejercicio 1
from text_stats import text_stats, text
text_stats(text)

# %%
# Ejercicio 2
from playlist_duration import playlist_durations, playlist
playlist_durations(playlist)

# %%
#Ejercicio 3
from spoiler_filter import replace_spoilers, review
replace_spoilers(review)

# %%
# Ejercicio 4
from email_validation import validate_email
validate_email()

# %%
# Ejercicio 5
from shipping_costs import calculate_costs
calculate_costs()

# %%
# Ejercicio 6
from hashtag_analysis import analyse_hashtag, posts
analyse_hashtag(posts)

# %%
# Ejercicio 7
from secret_santa import mix_up_list
mix_up_list()

# %%
# Ejercicio 8
from cipher import caesar_cipher
caesar_cipher()
# Out:
# Mensaje cifrado: Krod Pxqgr!! vrb brr Fklfrvvv
# Mensaje descifrado: Hola Mundo!! soy yoo Chicosss
